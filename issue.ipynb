# %%
file = open('finan.csv')
file.read()
# Out:
# '#NAME?,IM,RM,PP,IP,SP,BA,MR,MA,ML,BAN,ISR,IA,AA,EMR,S,IC,EI,DR,IF,Y\n8,10236.2,1,93.08,,6.92,1,44.64,84,5.96,8,1,10236.2,1279.525,1.07434465,6.92,1.34,0.1857,AAA,4,1.633918179\n12,11443,2,86.8,7.1,6.1,1,22.32,32.52,6.28,20,1,408.6785714,572.15,1.064962726,13.2,1.73,0.3322,AAA,4,1.242177815\n13,12773.24,2,87.7,6.3,6,1,14.16,29.88,6.33,20,1,510.9296,638.662,1.063829787,12.3,2.29,0.8992,AAA,4,1.657228959\n15,10933.17,1,86.89,7.63,5.48,1,14.64,38.76,6.25,24,1,437.3268,455.54875,1.057977148,13.11,3.31,0.6142,AAA,1,1.647644437\n18,2011.95,1,72.07,10.93,17,1,18.72,9.6,6.86,5,2,111.775,402.39,1.204819277,27.93,,,AA+,4,0.950085581\n20,5000,1,100,,,1,35.28,0.72,5,1,2,5000,5000,,,1.11,0.0298,AAA,4,1.264754501\n21,10824,1,81.49,11.36,7.15,1,16.2,35.33,6.09,21,1,541.2,515.4285714,1.077005924,18.51,2.86,0.5566,AAA,1,0.339692664\n22,13460.82,1,83.13,9.36,7.51,1,29.52,39.72,5.03,17,2,961.4871429,791.8129412,1.081197967,16.87,1.26,0.116,AAA,4,0.451565744\n23,13964.86,1,85.93,7.09,6.98,1,22.62,34.32,
# ...

# %%
import pandas as pd
file = pd.read_csv('finan.csv')
file.head()
# Out:
#    #NAME?        IM   RM     PP     IP     SP  BA     MR     MA    ML  \
# 0       8  10236.20  1.0  93.08    NaN   6.92   1  44.64  84.00  5.96
# 1      12  11443.00  2.0  86.80   7.10   6.10   1  22.32  32.52  6.28
# 2      13  12773.24  2.0  87.70   6.30   6.00   1  14.16  29.88  6.33
# 3      15  10933.17  1.0  86.89   7.63   5.48   1  14.64  38.76  6.25
# 4      18   2011.95  1.0  72.07  10.93  17.00   1  18.72   9.60  6.86
#
#      ...     ISR            IA          AA       EMR      S    IC      EI  \
# 0    ...     1.0  10236.200000  1279.52500  1.074345   6.92  1.34  0.1857
# 1    ...     1.0    408.678571   572.15000  1.064963  13.20  1.73  0.3322
# 2    ...     1.0    510.929600   638.66200  1.063830  12.30  2.29  0.8992
# 3    ...     1.0    437.326800   455.54875  1.057977  13.11  3.31  0.6142
# 4    ...     2.0    111.775000   402.39000  1.204819  27.93   NaN     NaN
#
#     DR   IF         Y
# 0  AAA  4.0  1.633918
# 1  AAA  4.0  1.242178
# 2  AAA  4.0  1.657229
# ...

# %%
file.rename(columns={'#NAME?':'SC'}, inplace = True)

# %%
file.head()
# Out:
#    SC        IM   RM     PP     IP     SP  BA     MR     MA    ML    ...     \
# 0   8  10236.20  1.0  93.08    NaN   6.92   1  44.64  84.00  5.96    ...
# 1  12  11443.00  2.0  86.80   7.10   6.10   1  22.32  32.52  6.28    ...
# 2  13  12773.24  2.0  87.70   6.30   6.00   1  14.16  29.88  6.33    ...
# 3  15  10933.17  1.0  86.89   7.63   5.48   1  14.64  38.76  6.25    ...
# 4  18   2011.95  1.0  72.07  10.93  17.00   1  18.72   9.60  6.86    ...
#
#    ISR            IA          AA       EMR      S    IC      EI   DR   IF  \
# 0  1.0  10236.200000  1279.52500  1.074345   6.92  1.34  0.1857  AAA  4.0
# 1  1.0    408.678571   572.15000  1.064963  13.20  1.73  0.3322  AAA  4.0
# 2  1.0    510.929600   638.66200  1.063830  12.30  2.29  0.8992  AAA  4.0
# 3  1.0    437.326800   455.54875  1.057977  13.11  3.31  0.6142  AAA  1.0
# 4  2.0    111.775000   402.39000  1.204819  27.93   NaN     NaN  AA+  4.0
#
#           Y
# 0  1.633918
# 1  1.242178
# 2  1.657229
# 3  1.647644
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 21 columns):
# SC     261 non-null int64
# IM     261 non-null float64
# RM     247 non-null float64
# PP     260 non-null float64
# IP     201 non-null float64
# SP     259 non-null float64
# BA     261 non-null int64
# MR     252 non-null float64
# MA     252 non-null float64
# ML     252 non-null float64
# BAN    255 non-null float64
# ISR    252 non-null float64
# IA     247 non-null float64
# AA     255 non-null float64
# EMR    259 non-null float64
# S      258 non-null float64
# IC     207 non-null float64
# EI     208 non-null object
# DR     257 non-null object
# IF     258 non-null float64
# Y      261 non-null float64
# dtypes: float64(17), int64(2), object(2)
# memory usage: 42.9+ KB

# %%
file["DR"].value_counts()
# Out:
# AAA    230
# Aa3     16
# AA+      8
# AA       1
# A+       1
# Aa       1
# Name: DR, dtype: int64

# %%
file["EI"].value_counts()
# Out:
# 0           7
# 0.1657      2
# 0.0923      2
# 0.9171      2
# 0.1928      2
# 0.2939      2
# 0.2023      1
# 0.7         1
# -0.3257     1
# -0.4561     1
# 0.0029      1
# 0.104       1
# 0.2737      1
# 0.4417      1
# 0.2603      1
# 0.1318      1
# -0.4958     1
# -0.0022     1
# 0.1053      1
# 0.6978      1
# 0.0957      1
# -3.3264     1
# 0.5245      1
# 0.5771      1
# 0.2125      1
# 0.9287      1
# 0.2081      1
# 0.7799      1
# 0.121       1
# 0.7304      1
#            ..
# -0.0157     1
# 0.6876      1
# -0.4731     1
# 0.4726      1
# 0.9174      1
# 0.8621      1
# 0.4505      1
# 0.1689      1
# 0.7068      1
# 0.6746      1
# 0.5738      1
# 0.5089      1
# 0.282       1
# 0.3867      1
# -1.0145     1
# 0.3057      1
# 0.0134      1
# 0.8525      1
# 0.7042      1
# 0.5136      1
# -49.0964    1
# -0.8679     1
# 0.0082      1
# -0.1663     1
# -0.0038     1
# 0.0038      1
# 0.1057      1
# 0.3322      1
# 0.85        1
# -0.4258     1
# ...

# %%
file.to_csv("fi.csv")

# %%
file = pd.read_csv("fi.csv")

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 22 columns):
# Unnamed: 0    261 non-null int64
# SC            261 non-null int64
# IM            261 non-null float64
# RM            247 non-null float64
# PP            260 non-null float64
# IP            201 non-null float64
# SP            259 non-null float64
# BA            261 non-null int64
# MR            252 non-null float64
# MA            252 non-null float64
# ML            252 non-null float64
# BAN           255 non-null float64
# ISR           252 non-null float64
# IA            247 non-null float64
# AA            255 non-null float64
# EMR           259 non-null float64
# S             258 non-null float64
# IC            207 non-null float64
# EI            208 non-null float64
# DR            257 non-null float64
# IF            258 non-null float64
# Y             261 non-null float64
# dtypes: float64(19), int64(3)
# memory usage: 44.9 KB

# %%
file.head()
# Out:
#    Unnamed: 0  SC        IM   RM     PP     IP     SP  BA     MR     MA  \
# 0           0   8  10236.20  1.0  93.08    NaN   6.92   1  44.64  84.00
# 1           1  12  11443.00  2.0  86.80   7.10   6.10   1  22.32  32.52
# 2           2  13  12773.24  2.0  87.70   6.30   6.00   1  14.16  29.88
# 3           3  15  10933.17  1.0  86.89   7.63   5.48   1  14.64  38.76
# 4           4  18   2011.95  1.0  72.07  10.93  17.00   1  18.72   9.60
#
#      ...     ISR            IA          AA       EMR      S    IC      EI  \
# 0    ...     1.0  10236.200000  1279.52500  1.074345   6.92  1.34  0.1857
# 1    ...     1.0    408.678571   572.15000  1.064963  13.20  1.73  0.3322
# 2    ...     1.0    510.929600   638.66200  1.063830  12.30  2.29  0.8992
# 3    ...     1.0    437.326800   455.54875  1.057977  13.11  3.31  0.6142
# 4    ...     2.0    111.775000   402.39000  1.204819  27.93   NaN     NaN
#
#     DR   IF         Y
# 0  4.0  4.0  1.633918
# 1  4.0  4.0  1.242178
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 22 columns):
# Unnamed: 0    261 non-null int64
# SC            261 non-null int64
# IM            261 non-null float64
# RM            247 non-null float64
# PP            260 non-null float64
# IP            201 non-null float64
# SP            259 non-null float64
# BA            261 non-null int64
# MR            252 non-null float64
# MA            252 non-null float64
# ML            252 non-null float64
# BAN           255 non-null float64
# ISR           252 non-null float64
# IA            247 non-null float64
# AA            255 non-null float64
# EMR           259 non-null float64
# S             258 non-null float64
# IC            207 non-null float64
# EI            208 non-null float64
# DR            257 non-null float64
# IF            258 non-null float64
# Y             261 non-null float64
# dtypes: float64(19), int64(3)
# memory usage: 44.9 KB

# %%
del file['Unnamed: 0']

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 21 columns):
# SC     261 non-null int64
# IM     261 non-null float64
# RM     247 non-null float64
# PP     260 non-null float64
# IP     201 non-null float64
# SP     259 non-null float64
# BA     261 non-null int64
# MR     252 non-null float64
# MA     252 non-null float64
# ML     252 non-null float64
# BAN    255 non-null float64
# ISR    252 non-null float64
# IA     247 non-null float64
# AA     255 non-null float64
# EMR    259 non-null float64
# S      258 non-null float64
# IC     207 non-null float64
# EI     208 non-null float64
# DR     257 non-null float64
# IF     258 non-null float64
# Y      261 non-null float64
# dtypes: float64(19), int64(2)
# memory usage: 42.9 KB

# %%
file.head()
# Out:
#    SC        IM   RM     PP     IP     SP  BA     MR     MA    ML    ...     \
# 0   8  10236.20  1.0  93.08    NaN   6.92   1  44.64  84.00  5.96    ...
# 1  12  11443.00  2.0  86.80   7.10   6.10   1  22.32  32.52  6.28    ...
# 2  13  12773.24  2.0  87.70   6.30   6.00   1  14.16  29.88  6.33    ...
# 3  15  10933.17  1.0  86.89   7.63   5.48   1  14.64  38.76  6.25    ...
# 4  18   2011.95  1.0  72.07  10.93  17.00   1  18.72   9.60  6.86    ...
#
#    ISR            IA          AA       EMR      S    IC      EI   DR   IF  \
# 0  1.0  10236.200000  1279.52500  1.074345   6.92  1.34  0.1857  4.0  4.0
# 1  1.0    408.678571   572.15000  1.064963  13.20  1.73  0.3322  4.0  4.0
# 2  1.0    510.929600   638.66200  1.063830  12.30  2.29  0.8992  4.0  4.0
# 3  1.0    437.326800   455.54875  1.057977  13.11  3.31  0.6142  4.0  1.0
# 4  2.0    111.775000   402.39000  1.204819  27.93   NaN     NaN  3.0  4.0
#
#           Y
# 0  1.633918
# 1  1.242178
# 2  1.657229
# 3  1.647644
# ...

# %%
file.describe()
# Out:
#                 SC            IM          RM          PP          IP  \
# count   261.000000    261.000000  247.000000  260.000000  201.000000
# mean    613.210728   4002.568102    1.190283   78.919000    9.952985
# std     392.006316   3293.833157    0.393322    9.833682    4.543649
# min       8.000000      0.000000    1.000000   44.640000    1.650000
# 25%     273.000000   1601.080000    1.000000   72.255000    6.530000
# 50%     579.000000   2998.060000    1.000000   81.275000    9.000000
# 75%     948.000000   4936.950000    1.000000   86.762500   12.700000
# max    1314.000000  16317.000000    2.000000  100.000000   25.720000
#
#                SP          BA          MR          MA         ML     ...      \
# count  259.000000  261.000000  252.000000  252.000000  252.00000     ...
# mean    13.362625    2.551724   37.015397   17.643611    6.71869     ...
# std      6.911398    2.150628   43.843534   18.160802    3.04403     ...
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
file.hist(bins=50, figsize=(20,15)) 
plt.show()

# %%
corr_matrix = file.corr()

# %%
corr_matrix["Y"].sort_values(ascending=False)
# Out:
# Y      1.000000
# SC     0.258972
# ML     0.185993
# S      0.144188
# IP     0.123906
# SP     0.089548
# EMR    0.079457
# IC     0.056467
# IA     0.027990
# AA    -0.014866
# RM    -0.015846
# IM    -0.026593
# BAN   -0.052167
# BA    -0.057027
# DR    -0.065142
# ISR   -0.067133
# IF    -0.087841
# MA    -0.110267
# MR    -0.133833
# PP    -0.137645
# EI    -0.230287
# Name: Y, dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["Y", "ML", "S","IP"]
scatter_matrix(file[attributes], figsize=(12, 8))
# Out:
# /Users/zhangfei/ml/env_3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111b1bd30>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1136736d8>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["Y", "MA", "MR","PP","EI"]
scatter_matrix(file[attributes], figsize=(12, 8))
# Out:
# /Users/zhangfei/ml/env_3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111c63c50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112699898>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["Y", "ML", "S","PP","EI"]
scatter_matrix(file[attributes], figsize=(12, 8))
# Out:
# /Users/zhangfei/ml/env_3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1120dff98>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111a9aeb8>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["Y", "EI"]
scatter_matrix(file[attributes], figsize=(12, 8))
# Out:
# /Users/zhangfei/ml/env_3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111d10358>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11148ffd0>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(file, test_size=0.2, random_state=42)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 212 to 102
# Data columns (total 21 columns):
# SC     208 non-null int64
# IM     208 non-null float64
# RM     195 non-null float64
# PP     207 non-null float64
# IP     156 non-null float64
# SP     206 non-null float64
# BA     208 non-null int64
# MR     200 non-null float64
# MA     201 non-null float64
# ML     199 non-null float64
# BAN    202 non-null float64
# ISR    201 non-null float64
# IA     195 non-null float64
# AA     202 non-null float64
# EMR    206 non-null float64
# S      206 non-null float64
# IC     162 non-null float64
# EI     163 non-null float64
# DR     205 non-null float64
# IF     206 non-null float64
# Y      208 non-null float64
# dtypes: float64(19), int64(2)
# memory usage: 35.8 KB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 30 to 178
# Data columns (total 21 columns):
# SC     53 non-null int64
# IM     53 non-null float64
# RM     52 non-null float64
# PP     53 non-null float64
# IP     45 non-null float64
# SP     53 non-null float64
# BA     53 non-null int64
# MR     52 non-null float64
# MA     51 non-null float64
# ML     53 non-null float64
# BAN    53 non-null float64
# ISR    51 non-null float64
# IA     52 non-null float64
# AA     53 non-null float64
# EMR    53 non-null float64
# S      52 non-null float64
# IC     45 non-null float64
# EI     45 non-null float64
# DR     52 non-null float64
# IF     52 non-null float64
# Y      53 non-null float64
# dtypes: float64(19), int64(2)
# memory usage: 9.1 KB

# %%
train_set.to_csv("train.csv")

# %%
test_set.to_csv("test.csv")

# %%
#Import libraries:
import pandas as pd
import numpy as np
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Perforing grid search

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

train = pd.read_csv('tr.csv')
target = 'Y'
# Out:
# /Users/zhangfei/ml/env_3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/zhangfei/ml/env_3/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 19 columns):
# IM     208 non-null float64
# RM     195 non-null float64
# PP     207 non-null float64
# IP     156 non-null float64
# SP     206 non-null float64
# BA     208 non-null int64
# MR     200 non-null float64
# MA     201 non-null float64
# ML     199 non-null float64
# ISR    201 non-null float64
# IA     195 non-null float64
# AA     202 non-null float64
# EMR    206 non-null float64
# S      206 non-null float64
# IC     162 non-null float64
# EI     163 non-null float64
# DR     205 non-null float64
# IF     206 non-null float64
# Y      208 non-null float64
# dtypes: float64(18), int64(1)
# memory usage: 31.0 KB

# %%
def modelfit(alg, dtrain, predictors,useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain[target].values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,metrics='auc', early_stopping_rounds=early_stopping_rounds,verbose_eval=True)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain['Y'],eval_metric='rmse')
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
    
    #Print model report:
    print ("\nModel Report")
                       
#Choose all predictors except target & IDcols
predictors = [x for x in train.columns if x not in [target]]
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'reg:linear',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb1, train, predictors)
# Out:
# [0]	train-auc:1.16027+0.0459129	test-auc:0.740109+0.179009
# [1]	train-auc:1.27766+0.0430919	test-auc:0.765911+0.220357
# [2]	train-auc:1.32107+0.0513881	test-auc:0.793293+0.242783
# [3]	train-auc:1.35985+0.0554452	test-auc:0.817214+0.298389
# [4]	train-auc:1.37784+0.0590635	test-auc:0.827234+0.274665
# [5]	train-auc:1.39924+0.0658521	test-auc:0.857644+0.27294
# [6]	train-auc:1.41801+0.069585	test-auc:0.851889+0.244347
# [7]	train-auc:1.43121+0.0686991	test-auc:0.843801+0.270432
# [8]	train-auc:1.44272+0.074701	test-auc:0.83464+0.270392
# [9]	train-auc:1.45203+0.0805567	test-auc:0.834429+0.268028
# [10]	train-auc:1.45966+0.0865799	test-auc:0.850155+0.299778
# [11]	train-auc:1.46792+0.0870067	test-auc:0.855664+0.282603
# [12]	train-auc:1.47798+0.0921173	test-auc:0.859227+0.297852
# [13]	train-auc:1.48032+0.0920781	test-auc:0.889855+0.32918
# [14]	train-auc:1.48606+0.0905351	test-auc:0.881399+0.319811
# [15]	train-auc:1.48951+0.0934021	test-auc:0.883935+0.325314
# ...

# %%
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=9,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'reg:linear',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb1, train, predictors)
# Out:
# [0]	train-auc:1.37561+0.0670026	test-auc:0.732457+0.241494
# [1]	train-auc:1.46502+0.0754254	test-auc:0.707734+0.144502
# [2]	train-auc:1.4814+0.0838654	test-auc:0.822686+0.324664
# [3]	train-auc:1.50279+0.0874523	test-auc:0.863416+0.389908
# [4]	train-auc:1.51704+0.0926272	test-auc:0.892116+0.386627
# [5]	train-auc:1.52879+0.0936038	test-auc:0.923669+0.431357
# [6]	train-auc:1.53555+0.0947364	test-auc:0.943696+0.44569
# [7]	train-auc:1.53811+0.0945456	test-auc:0.939477+0.405214
# [8]	train-auc:1.54137+0.0930428	test-auc:0.888333+0.391518
# [9]	train-auc:1.54423+0.0922579	test-auc:0.928229+0.428513
# [10]	train-auc:1.54868+0.0933485	test-auc:0.957695+0.441516
# [11]	train-auc:1.55147+0.0946973	test-auc:1.00022+0.495779
# [12]	train-auc:1.55527+0.0958844	test-auc:0.994973+0.495109
# [13]	train-auc:1.55665+0.0958544	test-auc:1.01077+0.499571
# [14]	train-auc:1.55816+0.0966688	test-auc:1.00474+0.518982
# [15]	train-auc:1.55968+0.0965068	test-auc:1.01186+0.534004
# ...

# %%
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=9,
 min_child_weight=1,
 gamma=0,
 subsample=0.7,
 colsample_bytree=0.8,
 objective= 'reg:linear',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb1, train, predictors)
# Out:
# [0]	train-auc:1.25777+0.0627171	test-auc:0.661051+0.286509
# [1]	train-auc:1.39267+0.0698792	test-auc:0.720232+0.36979
# [2]	train-auc:1.44072+0.0883821	test-auc:0.793706+0.305445
# [3]	train-auc:1.47+0.100571	test-auc:0.757284+0.294503
# [4]	train-auc:1.47784+0.0964969	test-auc:0.845322+0.352414
# [5]	train-auc:1.49756+0.101086	test-auc:0.882024+0.354524
# [6]	train-auc:1.51131+0.100898	test-auc:0.880521+0.368434
# [7]	train-auc:1.52061+0.0975299	test-auc:0.95322+0.452988
# [8]	train-auc:1.52708+0.0977608	test-auc:0.953164+0.435453
# [9]	train-auc:1.53224+0.0961776	test-auc:0.973038+0.421704
# [10]	train-auc:1.53812+0.0957658	test-auc:0.992213+0.441278
# [11]	train-auc:1.54051+0.0958474	test-auc:1.00366+0.4568
# [12]	train-auc:1.54337+0.0958455	test-auc:1.02733+0.500997
# [13]	train-auc:1.54538+0.0956276	test-auc:1.03473+0.523253
# [14]	train-auc:1.5477+0.0960141	test-auc:1.02381+0.497717
# [15]	train-auc:1.54913+0.0969727	test-auc:1.02615+0.509931
# ...

# %%
xgb1 = XGBClassifier(
 learning_rate =0.15,
 n_estimators=1000,
 max_depth=9,
 min_child_weight=1,
 gamma=0,
 subsample=0.7,
 colsample_bytree=0.8,
 objective= 'reg:linear',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb1, train, predictors)
# Out:
# [0]	train-auc:1.25777+0.0627171	test-auc:0.661051+0.286509
# [1]	train-auc:1.39865+0.0675028	test-auc:0.712883+0.353156
# [2]	train-auc:1.44704+0.0893908	test-auc:0.748752+0.316087
# [3]	train-auc:1.47436+0.102587	test-auc:0.773666+0.326861
# [4]	train-auc:1.48623+0.0937257	test-auc:0.846444+0.379363
# [5]	train-auc:1.50661+0.101735	test-auc:0.846867+0.374523
# [6]	train-auc:1.52026+0.0999361	test-auc:0.842293+0.38181
# [7]	train-auc:1.52784+0.0955813	test-auc:0.887874+0.448445
# [8]	train-auc:1.53551+0.0941791	test-auc:0.875562+0.436983
# [9]	train-auc:1.54033+0.0945729	test-auc:0.874698+0.4315
# [10]	train-auc:1.54627+0.0943123	test-auc:0.89462+0.437788
# [11]	train-auc:1.54998+0.094922	test-auc:0.899889+0.424496
# [12]	train-auc:1.55278+0.0947356	test-auc:0.906334+0.442064
# [13]	train-auc:1.55584+0.0947746	test-auc:0.921538+0.453685
# [14]	train-auc:1.55916+0.0956354	test-auc:0.923752+0.459603
# [15]	train-auc:1.56037+0.0963419	test-auc:0.92871+0.457483
# ...

# %%
params = {  
        'min_child_weight': 1,  
        'eta': 0.1,  
        'colsample_bytree': 0.8,  
        'max_depth': 9,  
        'subsample': 0.7,  
        'alpha': 0,  
        'gamma': 0,  
        'seed': 27,
        'objective':'reg:linear',
        'eval_metric': 'rmse',
        'scale_pos_weight': 1
    }
plst = params.items()
rounds = 37
y = train['Y']  
X = train.drop(['Y'], 1)  
  
xgtrain = xgb.DMatrix(X, label=y)
bst = xgb.train(plst, xgtrain, num_boost_round=rounds,verbose_eval= True)
bst.save_model('xgboost_ctr.model')

# %%
test = pd.read_csv("te.csv")
t_x = test.drop(['Y'], 1)
dtest = xgb.DMatrix(t_x)

preds = bst.predict(dtest)

# %%
test['pre'] = preds

# %%
test.head()
# Out:
#           IM   RM     PP     IP     SP  BA     MR     MA    ML  ISR  \
# 0  5273.8300  2.0  86.84   4.80   8.36   2  23.59   8.89  5.63  1.0
# 1  2985.0169  1.0  88.17   4.52   7.30   2  20.80  10.24  4.06  1.0
# 2  4857.9614  2.0  72.66  12.15  15.19   1  19.92   3.49  4.83  1.0
# 3  2855.4987  1.0  72.70   8.30  19.00   3  53.11   9.63  6.55  2.0
# 4  2156.1753  1.0  82.55   6.35  11.09   3  21.80  30.04  5.11  NaN
#
#            IA          AA       EMR      S    IC      EI   DR    IF         Y  \
# 0  585.981111  195.327037  1.091227  13.16  5.37  0.6974  4.0  12.0  0.568774
# 1  298.501690   96.290868  1.078749  11.82  1.51  0.1040  4.0  12.0  0.061860
# 2  285.762435  809.660233  1.179106  27.34  1.72  0.2999  4.0   4.0 -0.079528
# 3  571.099740  475.916450  1.234568  27.30  1.52  0.3406  4.0   4.0  0.570019
# 4  269.521912  215.617530  1.124733  17.44  1.55  0.2576  4.0   4.0 -0.270537
#
#         pre
# 0  0.914377
# 1  0.136852
# 2  0.324867
# 3  1.101712
# 4  0.098060

# %%
test.to_csv('result.csv')

# %%
sum_mean=0  
for i in range(len(preds)):  
    sum_mean+=(preds[i]-test['Y'].values[i])**2  
sum_erro=np.sqrt(sum_mean/len(preds))  
# calculate RMSE by hand  
print("RMSE by hand:",sum_erro)
# Out:
# RMSE by hand: 0.881317133942

# %%
plt.figure()  
plt.plot(range(len(preds)),preds,'b',label="predict")  
plt.plot(range(len(preds)),test['Y'],'r',label="test")  
plt.legend(loc="upper right") #显示图中的标签  
plt.xlabel("the number of sales")  
plt.ylabel('value of sales')  
plt.show()

# %%
import operator 
def ceate_feature_map(features):  
    outfile = open('xgb.fmap', 'w')  
    i = 0  
    for feat in features:  
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))  
        i = i + 1  
    outfile.close() 
features = [x for x in train.columns if x not in ['Y']]  
ceate_feature_map(features)  
  
importance = bst.get_fscore(fmap='xgb.fmap')  
importance = sorted(importance.items(), key=operator.itemgetter(1))  
  
df = pd.DataFrame(importance, columns=['feature', 'fscore'])  
df['fscore'] = df['fscore'] / df['fscore'].sum()  
df.to_csv("feat_importance.csv", index=False)  
  
plt.figure()  
df.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))  
plt.title('XGBoost Feature Importance')  
plt.xlabel('relative importance')  
plt.show()
